# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.datasets import load_files

# %%
with open('stop_word_list.txt', 'r') as f:
    stop_word_list = f.read().split('\n')
print(stop_word_list)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now']

# %%
services=load_files(container_path="services")
service_list=services.filenames
vectorizer =  TfidfVectorizer(stop_words=stop_word_list)
tfidf_data = vectorizer.fit_transform(services.data)
feature_names = vectorizer.get_feature_names()
print(tfidf_data.shape)
# Out:
# (5, 329)

# %%
def fearture_extraction(file_index):
    print(service_list[file_index])
    print("\n")
    for col in tfidf_data.nonzero()[1]:
        if tfidf_data[file_index,col]>0.1:
            print (feature_names[col], ' - ', tfidf_data[file_index,col])
    print("-------------------------------------------")

# %%
for i in range(5):
    fearture_extraction(i)
# Out:
# services/3/3_Group
#
#
# cbt  -  0.14179177380164032
# mood  -  0.14179177380164032
# anxiety  -  0.34319013092866907
# group  -  0.2287934206191127
# introduce  -  0.14179177380164032
# participants  -  0.21268766070246048
# therapy  -  0.21268766070246048
# manage  -  0.14179177380164032
# depression  -  0.2859917757738909
# strategies  -  0.14179177380164032
# managing  -  0.14179177380164032
# appropriate  -  0.21268766070246048
# students  -  0.17159506546433453
# experiencing  -  0.14179177380164032
# mild  -  0.21268766070246048
# moderate  -  0.21268766070246048
# mindfulness  -  0.21268766070246048
# thoughts  -  0.14179177380164032
# day  -  0.11439671030955635
# include  -  0.14179177380164032
# anxiety  -  0.34319013092866907
# depression  -  0.2859917757738909
# students  -  0.17159506546433453
# group  -  0.2287934206191127
# day  -  0.11439671030955635
# -------------------------------------------
# services/0/0_PSC.txt
#
#
# session  -  0.20744530764777458
# session  -  0.20744530764777458
# arrive  -  0.10325105649952385
# support  -  0.20744530764777458
# welcomed  -  0.10325105649952385
# receptionist  -  0.2065021129990477
# ask  -  0.10325105649952385
# sign  -  0.10325105649952385
# document  -  0.10325105649952385
# outlines  -  0.10325105649952385
# confidentiality  -  0.10325105649952385
# policy  -  0.10325105649952385
# afterwards  -  0.10325105649952385
# peer  -  0.3097531694985715
# supporter  -  0.3097531694985715
# bring  -  0.10325105649952385
# room  -  0.10325105649952385
# 45  -  0.10325105649952385
# minute  -  0.10325105649952385
# begins  -  0.10325105649952385
# discuss  -  0.10325105649952385
# anything  -  0.10325105649952385
# empathetically  -  0.10325105649952385
# judgmentally  -  0.10325105649952385
# well  -  0.10325105649952385
# practical  -  0.10325105649952385
# brainstorming  -  0.10325105649952385
# options  -  0.10325105649952385
# suggesting  -  0.10325105649952385
# developing  -  0.10325105649952385
# plan  -  0.10325105649952385
# move  -  0.10325105649952385
# forward  -  0.10325105649952385
# want  -  0.10325105649952385
# discussed  -  0.10325105649952385
# mind  -  0.10325105649952385
# given  -  0.10325105649952385
# post  -  0.10325105649952385
# questionnaire  -  0.10325105649952385
# great  -  0.10325105649952385
# opportunity  -  0.10325105649952385
# give  -  0.10325105649952385
# feedback  -  0.10325105649952385
# psc  -  0.2065021129990477
# continuously  -  0.10325105649952385
# improve  -  0.10325105649952385
# services  -  0.10325105649952385
# make  -  0.10325105649952385
# guarantee  -  0.10325105649952385
# moment  -  0.10325105649952385
# see  -  0.10325105649952385
# always  -  0.10325105649952385
# welcome  -  0.10325105649952385
# return  -  0.10325105649952385
# support  -  0.20744530764777458
# support  -  0.20744530764777458
# session  -  0.20744530764777458
# -------------------------------------------
# services/2/2_TAO.txt
#
#
# completed  -  0.15279326621032924
# completed  -  0.15279326621032924
# online  -  0.37876663030403596
# tao  -  0.473458287880045
# exercises  -  0.18938331515201798
# schedule  -  0.18938331515201798
# -------------------------------------------
# services/4/4_PhD
#
#
# group  -  0.3394197496857113
# support  -  0.1408745266398844
# life  -  0.1408745266398844
# support  -  0.1408745266398844
# life  -  0.1408745266398844
# program  -  0.1408745266398844
# feel  -  0.16970987484285566
# group  -  0.3394197496857113
# support  -  0.1408745266398844
# life  -  0.1408745266398844
# program  -  0.1408745266398844
# feel  -  0.16970987484285566
# phd  -  0.21035101551878008
# find  -  0.21035101551878008
# challenging  -  0.21035101551878008
# balance  -  0.21035101551878008
# academics  -  0.21035101551878008
# disconnected  -  0.21035101551878008
# others  -  0.21035101551878008
# sometimes  -  0.21035101551878008
# struggle  -  0.21035101551878008
# retain  -  0.21035101551878008
# focus  -  0.21035101551878008
# direction  -  0.21035101551878008
# join  -  0.21035101551878008
# ideas  -  0.21035101551878008
# encouragement  -  0.21035101551878008
# motivation  -  0.21035101551878008
# sense  -  0.21035101551878008
# connectedness  -  0.21035101551878008
# program  -  0.1408745266398844
# -------------------------------------------
# services/5/5_Tea
#
#
# based  -  0.1022907131877521
# questions  -  0.15343606978162816
# coffee  -  0.1022907131877521
# free  -  0.1022907131877521
# time  -  0.1022907131877521
# based  -  0.1022907131877521
# questions  -  0.15343606978162816
# coffee  -  0.1022907131877521
# free  -  0.1022907131877521
# time  -  0.1022907131877521
# vent  -  0.31696675601681606
# active  -  0.1267867024067264
# listening  -  0.2535734048134528
# need  -  0.1267867024067264
# empathetic  -  0.2535734048134528
# listener  -  0.1901800536100896
# shop  -  0.1267867024067264
# one  -  0.1901800536100896
# way  -  0.1267867024067264
# volunteers  -  0.1267867024067264
# reflective  -  0.1267867024067264
# regard  -  0.1267867024067264
# select  -  0.1267867024067264
# meet  -  0.1901800536100896
# café  -  0.1267867024067264
# venting  -  0.1267867024067264
# -------------------------------------------
